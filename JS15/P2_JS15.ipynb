# %% [markdown]
# <a href="https://colab.research.google.com/github/ekyaaa/2341720111_ML_2025/blob/main/JS15/P2_JS15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Langkah 1: Persiapan Environment

# %% [markdown]
# ## Langkah 2: Konfigurasi Server (app.py)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Langkah 3: Konfigurasi Dependencies (requirements.txt)

# %% [markdown]
# ## Langkah 4: Konfigurasi Docker (Dockerfile)

# %% [markdown]
# ## Langkah 5: Setup Hugging Face Space
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Langkah 6: Upload ke Cloud (Hugging Face)

# %% [markdown]
# ## Langkah 7: Pengujian dan Hasil Akhir
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
