# %% [markdown]
# ## Langkah 0 - Instal Library
#
# Pada praktikum ini kita akan menggunakan library pillow. Install pillow terlebih dahulu apabila belum terinstal di perangkat Anda.

# %%
# !pip install Pillow

# %% [markdown]
# ## Langkah 1 - Load Image

# %%
from PIL import Image

# Load gambar (pastikan path gambar benar, atau download Lenna.png)
# Untuk contoh, kita asumsikan gambar ada di folder img/
img = Image.open('/content/drive/MyDrive/ML_Dataset/lena.jpg')
img.show()  # tampilkan gambar
display(img)  # metode alternatif tampilkan gambar
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %% [markdown]
# ## Langkah 2 - Ekstrak Fitur
#
# Ekstrak setiap channel red, green, blue dan hitung histogramnya

# %%
# Ekstrak setiap channel red, green, blue
r, g, b = img.split()

# Cek panjang ukuran channel red
print(len(r.histogram()))

# Cetak fitur histogram pada channel red
print(r.histogram())
# Out:
# 256
# ...

# %% [markdown]
# ## Eksplorasi Tambahan
#
# Anda dapat mengeksplorasi histogram untuk channel G dan B, atau melakukan preprocessing seperti resize, grayscale, dll.

# %%
# Contoh: Histogram channel G
print("Histogram Green:")
print(g.histogram())

# Contoh: Convert to grayscale
gray_img = img.convert('L')
print("Grayscale image size:", gray_img.size)
display(gray_img)
# Out:
# Histogram Green:
# ...
